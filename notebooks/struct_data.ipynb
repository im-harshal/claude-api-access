# %%
# Load env variables
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Create an API client
from anthropic import Anthropic
client = Anthropic()
model = "claude-sonnet-4-0"

# %%
# Helper function to add user and assistant messages to list and call claude api
def add_user_message(messages, text):
    user_message = { "role":"user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = { "role":"assistant", "content": text}
    messages.append(assistant_message)

# %%
def chat(messages, stop_sequences):
    message = client.messages.create(
        model = model,
        max_tokens = 1000,
        messages = messages,
        stop_sequences= stop_sequences
    )
    return message.content[0].text

# %%
messages = []

add_user_message(messages, "Generate a short event bridge rule in json")

add_assistant_message(messages, "```json")

text = chat(messages, stop_sequences=["```"])
text
# Out:
# '\n{\n  "Name": "UserRegistrationRule",\n  "EventPattern": {\n    "source": ["myapp.users"],\n    "detail-type": ["User Registration"],\n    "detail": {\n      "status": ["completed"]\n    }\n  },\n  "State": "ENABLED",\n  "Targets": [\n    {\n      "Id": "1",\n      "Arn": "arn:aws:lambda:us-east-1:123456789012:function:ProcessNewUser"\n    }\n  ]\n}\n'

# %%
import json

json.loads(text.strip(""))
# Out:
# {'Name': 'UserRegistrationRule',
#  'EventPattern': {'source': ['myapp.users'],
#   'detail-type': ['User Registration'],
#   'detail': {'status': ['completed']}},
#  'State': 'ENABLED',
#  'Targets': [{'Id': '1',
#    'Arn': 'arn:aws:lambda:us-east-1:123456789012:function:ProcessNewUser'}]}
